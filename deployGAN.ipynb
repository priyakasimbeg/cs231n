# %%
from gan.utils import *
from gan.gan import *
from gan.evaluation_utils import *
from gan.metrics import *
from matplotlib import pyplot as plt
import matplotlib as mpl
import tensorflow as tf
# %matplotlib inline
# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Train and evaluate a SRGAN

# %%
NAME = 'L1'

## Achitecture Settings
N_RES = 7

## Optimization settings
DLR = 2.5e-6
GLR = 2e-5
BETA1 = 0.9

DLR2 = 2e-6
GLR2 = 6e-6

STEPS = 4 # number of G updates per D update

# Loss functions settings
GEN_REG = 5e4
FEAT_REG = 1e-1

L1_REG = True
TV_REG = 0
VGG_REG = False

BATCH_SIZE = 50

# %%
# Construct a SRGAN model
srgan = SRGAN(N_RES) #Try 2

# Use the function you wrote earlier to get optimizers for the Discriminator and the Generator
D_solver, G_solver = get_solvers(dlr=DLR, glr=GLR, beta1=BETA1) #8e-7, 1.2e-7, 

#Define loss object 
#Constructor API
# __init__(self, gen_reg, tv_reg, feat_reg, l1_reg=True, vgg_reg=False, 
#                  ls_disc=False)
losses = Loss(gen_reg=GEN_REG, tv_reg=TV_REG, l1_reg=L1_REG, feat_reg=FEAT_REG, vgg_reg=VGG_REG)
validation_losses = Loss(gen_reg=GEN_REG, tv_reg=TV_REG,  l1_reg=L1_REG, feat_reg=FEAT_REG, vgg_reg=VGG_REG)

# Run it!
g_errors, d_errors  = run_a_gan(srgan, D_solver, G_solver, losses, validation_losses,
                                num_epochs=5, batch_size=BATCH_SIZE, show_every=5,
                                late_dlr=DLR2, late_glr=GLR2, 
                                gen_steps_per_discrimination=STEPS,
                               model_name=NAME)
plt.title('G errors')
plt.plot(g_errors)
plt.yscale('log')
plt.show()

plt.title('D errors')
plt.plot(d_errors)
plt.show()
# Out:
# Epoch: 0, Iter: 0, D: 0.5004, G:3.705e+04
# Epoch: 1, Iter: 5, D: 0.4877, G:3.594e+04
# Epoch: 2, Iter: 10, D: 0.4793, G:3.561e+04
# Epoch: 3, Iter: 15, D: 0.4714, G:3.536e+04
# Final images

# %% [markdown]
# ## Run evaluation

# %%
plot_train_val_loss(losses, validation_losses, NAME)
p, s = runEvaluation(NAME)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-bfb79f8dc21c> in <module>
#       1 plot_train_val_loss(losses, validation_losses, NAME)
# ----> 2 p, s = runEvaluation(NAME)
#
# /home/shared/cs231n/gan/evaluation_utils.py in runEvaluation(model_name, i)
#      84
#      85     test_in, test_out, fig = runTest(model_name)
# ---> 86     test_in_tensor = array_batch_to_tensor(test_in)
#      87     test_out_tensor = array_batch_to_tensor(test_out)
#      88
#
# NameError: name 'array_batch_to_tensor' is not defined

# %%
#Extract plots of losses as dictionary loss name -> loss plot
plots = losses.get_loss_plots()
