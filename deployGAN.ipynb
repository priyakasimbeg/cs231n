# %%
from gan.utils import *
from gan.gan import *
from matplotlib import pyplot as plt
# %matplotlib inline
# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Train and evaluate a DCGAN

# %%
# Construct a DCGAN model
dcgan = DCGAN()

# Use the function you wrote earlier to get optimizers for the Discriminator and the Generator
D_solver, G_solver = get_solvers()

# Run it!
g_errors, d_errors  = run_a_gan(dcgan.D, dcgan.G, D_solver, G_solver, discriminator_loss, generator_loss, 
                                num_epochs=300, batch_size=100)
# Out:
# Epoch: 0, Iter: 0, D: 1.298, G:2.251e+04
# Epoch: 6, Iter: 20, D: 0.4666, G:4.955
# Epoch: 13, Iter: 40, D: 0.1243, G:6.964
# Epoch: 20, Iter: 60, D: 0.03071, G:11.48
# Epoch: 26, Iter: 80, D: 0.008194, G:1.845
# Epoch: 33, Iter: 100, D: 0.001691, G:0.5433
# Epoch: 40, Iter: 120, D: 0.0006398, G:0.4745
# Epoch: 46, Iter: 140, D: 0.0001783, G:0.4966
# Epoch: 53, Iter: 160, D: 4.017e-05, G:0.5118
# Epoch: 60, Iter: 180, D: 1.8e-05, G:0.4925
# Epoch: 66, Iter: 200, D: 5.704e-06, G:0.583
# Epoch: 73, Iter: 220, D: 1.489e-06, G:6.331
# Epoch: 80, Iter: 240, D: 8.914e-07, G:29.12
# Epoch: 86, Iter: 260, D: 3.245e-07, G:26.18
# Epoch: 93, Iter: 280, D: 9.183e-08, G:14.07
# Epoch: 100, Iter: 300, D: 4.386e-08, G:1.599
# Epoch: 106, Iter: 320, D: 2.862e-08, G:0.7407
# Epoch: 113, Iter: 340, D: 1.056e-08, G:0.498
# Epoch: 120, Iter: 360, D: 9.197e-09, G:0.4577
# Epoch: 126, Iter: 380, D: 6.963e-09, G:0.4712
# Epoch: 133, Iter: 400, D: 2.682e-09, G:0.4865
# ...

# %% [markdown]
# ## Train and evaluate a SRGAN

# %%
import time

# %%
# %%time

# with strategy.scope():
# Construct a SRGAN model
srgan = SRGAN(7) #Try 2

# Use the function you wrote earlier to get optimizers for the Discriminator and the Generator
D_solver, G_solver = get_solvers(dlr=2e-6, glr=1.7e-6, beta1=0.9) #8e-7, 1.2e-7, 

# Run it!
g_errors, d_errors  = run_a_gan(srgan.D, srgan.G, D_solver, G_solver, discriminator_loss, 
                                generator_loss, num_epochs=400, batch_size=100, show_every=50,
                                gen_reg = 5e-2, tv_reg=0, feat_reg=0, #12e-6, 1e-6, 1e-1
                                late_dlr=2e-6, late_glr=6e-6, 
                                gen_steps_per_discrimination=4)
plt.plot(g_errors)
plt.yscale('log')
plt.show()

plt.plot(d_errors)
plt.show()
# Out:
# Epoch: 0, Iter: 0, D: 1.387, G:7.82e+03
# Epoch: 16, Iter: 50, D: 1.359, G:4.194e+03
# Epoch: 33, Iter: 100, D: 1.318, G:4.181e+03
# Epoch: 50, Iter: 150, D: 1.249, G:3.846e+03
# Epoch: 66, Iter: 200, D: 1.141, G:3.936e+03
# Epoch: 83, Iter: 250, D: 1.001, G:4e+03
# Epoch: 100, Iter: 300, D: 0.851, G:3.716e+03
# Epoch: 116, Iter: 350, D: 0.7316, G:3.831e+03
# Epoch: 133, Iter: 400, D: 0.6613, G:3.888e+03
# Epoch: 150, Iter: 450, D: 0.6102, G:3.737e+03
# Epoch: 166, Iter: 500, D: 0.5388, G:3.738e+03

# %%
for x in EPID(batch_size=100):
    show_images(x[0:25])
    break

# %%
for x in PHANTOM(batch_size=100):
    show_images(x[0:25])
    break
