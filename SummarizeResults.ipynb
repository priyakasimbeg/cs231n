# %%
from gan.utils import *
from gan.gan import *
from gan.evaluation_utils import *
from gan.metrics import *
from matplotlib import pyplot as plt
import matplotlib as mpl

import pandas as pd

# %matplotlib inline
# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
NAMES = ['L1', 'L2', 'TV','VGG']

# %% [markdown]
# ## Compare L1 and L2

# %%
errors, fig = compareModels(NAMES[:2])

# %%
names = errors.keys()
metric_names = ['PSNR', 'SSIM']

data = np.zeros((len(metric_names), len(names)))

for i, name in enumerate(names):
    data[:, i] = errors[name]

df = pd.DataFrame(data, columns=names, index=metric_names)
df
# Out:
#              L1         L2
# PSNR  33.788891  17.017603
# SSIM   0.976806   0.248709

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{lrr}
# \toprule
# {} &         L1 &         L2 \\
# \midrule
# PSNR &  33.788891 &  17.017603 \\
# SSIM &   0.976806 &   0.248709 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Compare L1 and +VGG and +TV

# %%
errors, fig = compareModels(['L1', 'VGG', 'TV'])

# %%
names = errors.keys()
metric_names = ['PSNR', 'SSIM']

data = np.zeros((len(metric_names), len(names)))

for i, name in enumerate(names):
    data[:, i] = errors[name]

df = pd.DataFrame(data, columns=names, index=metric_names)
df
# Out:
#              L1        VGG         TV
# PSNR  33.788891  32.582005  34.065636
# SSIM   0.976806   0.974190   0.977433

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
# {} &         L1 &        VGG &         TV \\
# \midrule
# PSNR &  33.788891 &  32.582005 &  34.065636 \\
# SSIM &   0.976806 &   0.974190 &   0.977433 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Evaluation on real data

# %%
errors, fig = compareMethods('TV')
# Out:
# tf.Tensor([50 32 32  1], shape=(4,), dtype=int32)

# %%
errors
# Out:
# {'TV': [24.575342, 0.7992654], 'Wiener': [35.770767, 0.91918397]}

# %%
names = ['TV', 'Wiener']
metric_names = ['PSNR', 'SSIM']

data = np.zeros((len(metric_names), len(names)))

for i, name in enumerate(names):
    data[:, i] = errors[name]

df = pd.DataFrame(data, columns=names, index=metric_names)
df
# Out:
#              TV     Wiener
# PSNR  24.575342  35.770767
# SSIM   0.799265   0.919184

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{lrr}
# \toprule
# {} &         TV &     Wiener \\
# \midrule
# PSNR &  24.575342 &  35.770767 \\
# SSIM &   0.799265 &   0.919184 \\
# \bottomrule
# \end{tabular}
